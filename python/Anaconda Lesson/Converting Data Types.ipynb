# %% [markdown]
# #Converting Data Types

# %%
num_int = 7

# %%
type (num_int)
# Out:
# int

# %%
num_int_str = '7'

# %%
type(num_int_str)
# Out:
# str

# %%
num_sum = num_int+num_int

# %%
num_sum
# Out:
# 14

# %%
num_int_str_conv = int(num_int_str)

# %%
type (num_int_str)
# Out:
# str

# %%
num_int_str_co =  int(num_int_str)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 num_int_str_co =  int(num_int_str)
#
# NameError: name 'num_int_str' is not defined

# %%
num_int_str = '7'

# %%
type(num_int_str)
# Out:
# str

# %%
num_int_str_con = int (num_int_str)

# %%
type(num_int_str_con)
# Out:
# int

# %%
sum_num = num_int + num_int_str_con

# %%
sum_num
# Out:
# 14

# %%
list_type = [1,2,3]

# %%
type (list_type)
# Out:
# list

# %%
tuple (list_type)
# Out:
# (1, 2, 3)

# %%
type(tuple (list_type))
# Out:
# tuple

# %%
list_type2=[1,2,3,3,2,1,2,1,2,1,2]

# %%
set(list_type2)
# Out:
# {1, 2, 3}

# %%
type(set(list_type2))
# Out:
# set

# %%
dict_type = {'name': 'Alex', 'age': 28, 'hair': 'N/A'}

# %%
type(dict_type)
# Out:
# dict

# %%
dict_type.items()
# Out:
# dict_items([('name', 'Alex'), ('age', 28), ('hair', 'N/A')])

# %%
dict_type.values()
# Out:
# dict_values(['Alex', 28, 'N/A'])

# %%
dict_type.keys()
# Out:
# dict_keys(['name', 'age', 'hair'])

# %%
list(dict_type.values())
# Out:
# ['Alex', 28, 'N/A']

# %%
type(list(dict_type.values()))
# Out:
# list

# %%
long_stri = 'I like to party'

# %%
set (long_stri)
# Out:
# {' ', 'I', 'a', 'e', 'i', 'k', 'l', 'o', 'p', 'r', 't', 'y'}

# %%
dict_type = {'name': 'Alex', 'age': 28, 'hair': 'N/A'}

# %%
weight = input("Enter your weight in pound:   ")
height = input("Enter your height in inches:  ")
