# %% [markdown]
# ###function

# %%
def first_function():
    print('We did it')

# %%
first_function()
# Out:
# We did it

# %%
def number_squared(number):
    print(number**2)

# %%
number_squared(5)
# Out:
# 25

# %%
number_squared(10)
# Out:
# 100

# %%
number_squared(number):

# %%
def number_squared(number, power):
    print(number**power)

# %%
def number_squared(number, power):
    print(number**power)

# %%
 number_squared(5,3)
# Out:
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# ...

# %%
def number_squared_cus(number,power):
    print (number**power)

# %%
number_squared_cus(2,3)
# Out:
# 8

# %%
def num_args(*number):
   print (number[0]*number [1])

# %%
num_args(5,6,1,2,8)
# Out:
# 30

# %%
def num_args_2(*number):
   print (number[1]*number [3])

# %%
num_args_2(5,6,1,2,8)
# Out:
# 12

# %%
tulpe_args = (5,6,1,2,8)

# %%
num_args = (*tulpe_args)
# Out:
#   Cell In[19], line 1
#     num_args = (*tulpe_args)
#                 ^
# SyntaxError: cannot use starred expression here

# %%
tulpe_args = (5,6,1,2,8)

# %%
number_tulpe (*tulpe_args)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 number_tulpe (*tulpe_args)
#
# TypeError: 'tuple' object is not callable

# %%
args_tuple = (5,6,1,2,6)

# %%
num_args(*args_tuple)
# Out:
# 30

# %%
def number_squared_cus(number, power):
    print(number**power)

# %%
number_squared_cus(number = 5, power = 3)
# Out:
# 125

# %%
number_squared_cus(number = 3, power = 5)
# Out:
# 243

# %%
3*3*3*3*3
# Out:
# 243

# %%
def num_kwarg(**number):
    print('My number is :' + number ['integer'])

# %%
num_kwarg(integer = 2309)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 num_kwarg(integer = 2309)
#
# Cell In[40], line 2, in num_kwarg(**number)
#       1 def num_kwarg(**number):
# ----> 2     print('My number is :' + number ['integer'])
#
# TypeError: can only concatenate str (not "int") to str

# %%
def number_kwarg(**number):
    print('My number is: '+ number ['integer'])

# %%
number_kwarg(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 number_kwarg(1)
#
# TypeError: number_kwarg() takes 0 positional arguments but 1 was given

# %%
def number_kwarg(**number):
    print('My number is: '+ number ['integer'])

# %%
number_kwarg(integer = '2309')
# Out:
# My number is: 2309

# %%
def number_kwarg(**number):
    print('My number is: '+ number ['integer'] + 'My Other number:' + number ['integer2'] )

# %%
number_kwarg(integer = '102', integer2 = '111')
# Out:
# My number is: 102My Other number:111
