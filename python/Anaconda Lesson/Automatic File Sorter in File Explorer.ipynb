# %% [markdown]
# Automatic File Sorter in File Explorer

# %%
import os, shutil

# %%
path = r"/Users/apple/Downloads/Day 2"

# %%
file_name = os.listdir(path)
#show all the files in path

# %%
print (file_name)
# Out:
# ['DAY 2.mp4', '{8E27488B-0957-4D1C-A20A-14A5EF1F1DFF}.png', 'Essential PowerBiClass.pbit', 'SQL_Tutorial_Lesson_Solution.docx', 'class_work.pbix', 'Dim_Team.csv', 'worldcup_star_schema.sql', '{ED60671D-5658-461E-8774-BD3FD592E54F}.png', 'Fact_Schedule.csv', 'Dim_Date.csv', 'Essential PowerBiClass.pbix', 'Fact_Ranking.csv', 'Dim_Tournament.csv', 'PowerBI_Tutorial_Lesson_Solution.docx', 'Dim_Round.csv', 'Fact_Match.csv']

# %%
os.path.exists(path+ 'csv files')
# Out:
# False

# %%
folder_names = ['csv files', 'image files', 'docx files']

for loop in range (0,3):
   if not os.path.exists(path + folder_names[loop]):
        #print (path + folder_names[loop])
        os.makedirs(path + folder_names[loop])

# %%
for file in file_name:
    if ".csv" in file and not os.path.exists(path+"csv files/" + file):
        shutil.move(path+file,path + "csv files/" + file)
    elif ".png" in file and not os.path.exists (path+"image files/" + file):
        shutil.move(path+file,path + "image files/" + file)
    elif ".docx" in file and not os.path.exists (path+"text files/" + file):
        shutil.move(path+file,path + "docx files/" + file)
    else:
        print("there are files in this path that were not moved!")
