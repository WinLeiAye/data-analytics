# %%
import pandas as pd

# %%
df = pd.read_excel('/Users/apple/Projects/personal/python/Anaconda Lesson/data of pandas reading exercise /Customer Call List.xlsx')

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
type ('customer ID')
# Out:
# str

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df = df.drop(columns = "Not_Useful_Column" )

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df["Last_Name"].str.strip()
# Out:
# 0         Baggins
# 1           Nadir
# 2          /White
# 3         Schrute
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         Gamgee
# 11      ...Potter
# 12         Draper
# 13          Knope
# 14    Flenderson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# Name: Last_Name, dtype: object

# %%
df["Last_Name"].str.lstrip("...")
# Out:
# 0         Baggins
# 1           Nadir
# 2          /White
# 3         Schrute
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         Gamgee
# 11         Potter
# 12         Draper
# 13          Knope
# 14    Flenderson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# Name: Last_Name, dtype: object

# %%
df["Last_Name"].str.lstrip("/")
# Out:
# 0         Baggins
# 1           Nadir
# 2           White
# 3         Schrute
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         Gamgee
# 11      ...Potter
# 12         Draper
# 13          Knope
# 14    Flenderson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# Name: Last_Name, dtype: object

# %%
df["Last_Name"].str.lstrip(["/","..."])
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# Name: Last_Name, dtype: float64

# %%
df["Last_Name"].str.lstrip()
# Out:
# 0         Baggins
# 1           Nadir
# 2          /White
# 3         Schrute
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         Gamgee
# 11      ...Potter
# 12         Draper
# 13          Knope
# 14    Flenderson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# Name: Last_Name, dtype: object

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df["Last_Name"]=df["Last_Name"].str.strip("...")

# %%
df["Last_Name"]
# Out:
# 0         Baggins
# 1           Nadir
# 2          /White
# 3         Schrute
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         Gamgee
# 11         Potter
# 12         Draper
# 13          Knope
# 14    Flenderson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# Name: Last_Name, dtype: object

# %%
df["Last_Name"]=df["Last_Name"].str.strip("/")

# %%
df["Last_Name"]
# Out:
# 0         Baggins
# 1           Nadir
# 2           White
# 3         Schrute
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         Gamgee
# 11         Potter
# 12         Draper
# 13          Knope
# 14    Flenderson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# Name: Last_Name, dtype: object

# %%
df["Last_Name"]=df["Last_Name"].str.rstrip("_")
# can also write like this _df["Last_Name"]=df["Last_Name"].str.strip("123._/")

# %%
df["Last_Name"]
# Out:
# 0        Baggins
# 1          Nadir
# 2          White
# 3        Schrute
# 4           Snow
# 5        Swanson
# 6         Winger
# 7         Holmes
# 8            NaN
# 9         Parker
# 10        Gamgee
# 11        Potter
# 12        Draper
# 13         Knope
# 14    Flenderson
# 15       Weasley
# 16         Scott
# 17          Kent
# 18        Braton
# 19     Skywalker
# Name: Last_Name, dtype: object

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %%
df['Phone_Number'].str.replace('[^a-zA-Z0-9]','')
# Out:
# 0     123--54-5-54
# 1     123--64-3-97
# 2     706--69-5-03
# 3     123--54-3-23
# 4     876--67-8-34
# 5     304--76-2-24
# 6             ----
# 7     876--67-8-34
# 8             ----
# 9     123--54-5-54
# 10            ----
# 11    706--69-5-03
# 12    123--54-3-23
# 13    876--67-8-34
# 14    304--76-2-24
# 15    123--54-5-54
# 16    123--64-3-97
# 17    706--69-5-03
# 18            ----
# 19    876--67-8-34
# Name: Phone_Number, dtype: object

# %%
df["Phone_Number"] = df["Phone_Number"].astype(str).str.replace(r'[^0-9]', '', regex=True)

# %%
df["Phone_Number"]
# Out:
# 0     12354554
# 1     12364397
# 2     70669503
# 3     12354323
# 4     87667834
# 5     30476224
# 6
# 7     87667834
# 8
# 9     12354554
# 10
# 11    70669503
# 12    12354323
# 13    87667834
# 14    30476224
# 15    12354554
# 16    12364397
# 17    70669503
# 18
# 19    87667834
# Name: Phone_Number, dtype: object

# %%
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins     12354554
# 1         1002       Abed       Nadir     12364397
# 2         1003     Walter       White     70669503
# 3         1004     Dwight     Schrute     12354323
# 4         1005        Jon        Snow     87667834
# 5         1006        Ron     Swanson     30476224
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes     87667834
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker     12354554
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter     70669503
# 12        1013        Don      Draper     12354323
# 13        1014     Leslie       Knope     87667834
# 14        1015       Toby  Flenderson     30476224
# 15        1016        Ron     Weasley     12354554
# 16        1017   Michael        Scott     12364397
# 17        1018      Clark        Kent     70669503
# ...

# %%
df["Phone_Number"].apply(lambda x: str(x))
df["Phone_Number"]=df["Phone_Number"].apply(lambda x: x[0:3]+ '-' + x[3:6]+'-'+ x[6:10])

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White  706-695-0392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger            --
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN            --
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee            --
# 11        1012      Harry      Potter  706-695-0392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# ...

# %%
df["Phone_Number"]=df["Phone_Number"].str.replace('--','')

# %%
df["Phone_Number"]
# Out:
# 0     123-545-5421
# 1     123-643-9775
# 2     706-695-0392
# 3     123-543-2345
# 4     876-678-3469
# 5     304-762-2467
# 6
# 7     876-678-3469
# 8
# 9     123-545-5421
# 10
# 11    706-695-0392
# 12    123-543-2345
# 13    876-678-3469
# 14    304-762-2467
# 15    123-545-5421
# 16    123-643-9775
# 17    706-695-0392
# 18
# 19    876-678-3469
# Name: Phone_Number, dtype: object

# %%
df["Last_Name"]=df["Last_Name"].str.replace('NaN','')
df["Last_Name"]
# Out:
# 0        Baggins
# 1          Nadir
# 2          White
# 3        Schrute
# 4           Snow
# 5        Swanson
# 6         Winger
# 7         Holmes
# 8            NaN
# 9         Parker
# 10        Gamgee
# 11        Potter
# 12        Draper
# 13         Knope
# 14    Flenderson
# 15       Weasley
# 16         Scott
# 17          Kent
# 18        Braton
# 19     Skywalker
# Name: Last_Name, dtype: object

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White  706-695-0392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter  706-695-0392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent  706-695-0392
# ...

# %%
df["Address"].str.split(',',1, expand = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 df["Address"].str.split(',',1, expand = True)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/strings/accessor.py:140, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     135     msg = (
#     136         f"Cannot use .str.{func_name} with values of "
#     137         f"inferred dtype '{self._inferred_dtype}'."
#     138     )
#     139     raise TypeError(msg)
# --> 140 return func(self, *args, **kwargs)
#
# TypeError: StringMethods.split() takes from 1 to 2 positional arguments but 3 positional arguments (and 1 keyword-only argument) were given

# %%
df[["Street Address", "State", "Zip"]] = df["Address"].astype(str).str.split(',', n=2, expand=True)

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123--54-5-54
# 1         1002       Abed       Nadir  123--64-3-97
# 2         1003     Walter       White  706--69-5-03
# 3         1004     Dwight     Schrute  123--54-3-23
# 4         1005        Jon        Snow  876--67-8-34
# 5         1006        Ron     Swanson  304--76-2-24
# 6         1007       Jeff      Winger          ----
# 7         1008   Sherlock      Holmes  876--67-8-34
# 8         1009    Gandalf         NaN          ----
# 9         1010      Peter      Parker  123--54-5-54
# 10        1011    Samwise      Gamgee          ----
# 11        1012      Harry      Potter  706--69-5-03
# 12        1013        Don      Draper  123--54-3-23
# 13        1014     Leslie       Knope  876--67-8-34
# 14        1015       Toby  Flenderson  304--76-2-24
# 15        1016        Ron     Weasley  123--54-5-54
# 16        1017   Michael        Scott  123--64-3-97
# ...

# %%
df["Phone_Number"].astype(str).replace('--','')
# Out:
# 0     123--54-5-54
# 1     123--64-3-97
# 2     706--69-5-03
# 3     123--54-3-23
# 4     876--67-8-34
# 5     304--76-2-24
# 6             ----
# 7     876--67-8-34
# 8             ----
# 9     123--54-5-54
# 10            ----
# 11    706--69-5-03
# 12    123--54-3-23
# 13    876--67-8-34
# 14    304--76-2-24
# 15    123--54-5-54
# 16    123--64-3-97
# 17    706--69-5-03
# 18            ----
# 19    876--67-8-34
# Name: Phone_Number, dtype: object

# %%
df["Phone_Number"]=df["Phone_Number"].apply(lambda x: x[0:3]+ '-' + x[3:6]+'-'+ x[6:10])

# %%
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   123-545-54
# 1         1002       Abed       Nadir   123-643-97
# 2         1003     Walter       White   706-695-03
# 3         1004     Dwight     Schrute   123-543-23
# 4         1005        Jon        Snow   876-678-34
# 5         1006        Ron     Swanson   304-762-24
# 6         1007       Jeff      Winger           --
# 7         1008   Sherlock      Holmes   876-678-34
# 8         1009    Gandalf         NaN           --
# 9         1010      Peter      Parker   123-545-54
# 10        1011    Samwise      Gamgee           --
# 11        1012      Harry      Potter   706-695-03
# 12        1013        Don      Draper   123-543-23
# 13        1014     Leslie       Knope   876-678-34
# 14        1015       Toby  Flenderson   304-762-24
# 15        1016        Ron     Weasley   123-545-54
# 16        1017   Michael        Scott   123-643-97
# ...

# %%
df["Address"].astype(str).str.split(',',n=2, expand = True)
# Out:
#                        0              1       2
# 0         123 Shire Lane          Shire    None
# 1    93 West Main Street           None    None
# 2     298 Drugs Driveway           None    None
# 3       980 Paper Avenue   Pennsylvania   18503
# 4       123 Dragons Road           None    None
# 5       768 City Parkway           None    None
# 6      1209 South Street           None    None
# 7          98 Clue Drive           None    None
# 8       123 Middle Earth           None    None
# 9       25th Main Street       New York    None
# 10        612 Shire Lane          Shire    None
# 11  2394 Hogwarts Avenue           None    None
# 12      2039 Main Street           None    None
# 13      343 City Parkway           None    None
# 14         214 HR Avenue           None    None
# 15  2395 Hogwarts Avenue           None    None
# 16      121 Paper Avenue   Pennsylvania    None
# 17       3498 Super Lane           None    None
# 18                   N/a           None    None
# ...

# %%
df[["Street Address", "State", "Zip"]] = df["Address"].astype(str).str.split(',',n=2, expand = True)

# %%
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   123-545-54
# 1         1002       Abed       Nadir   123-643-97
# 2         1003     Walter       White   706-695-03
# 3         1004     Dwight     Schrute   123-543-23
# 4         1005        Jon        Snow   876-678-34
# 5         1006        Ron     Swanson   304-762-24
# 6         1007       Jeff      Winger           --
# 7         1008   Sherlock      Holmes   876-678-34
# 8         1009    Gandalf         NaN           --
# 9         1010      Peter      Parker   123-545-54
# 10        1011    Samwise      Gamgee           --
# 11        1012      Harry      Potter   706-695-03
# 12        1013        Don      Draper   123-543-23
# 13        1014     Leslie       Knope   876-678-34
# 14        1015       Toby  Flenderson   304-762-24
# 15        1016        Ron     Weasley   123-545-54
# 16        1017   Michael        Scott   123-643-97
# ...

# %%
df["Paying Customer"]= df["Paying Customer"].str.replace('Yes', 'Y')
df["Paying Customer"]=df["Paying Customer"].str.replace('No', 'N')

# %%
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   123-545-54
# 1         1002       Abed       Nadir   123-643-97
# 2         1003     Walter       White   706-695-03
# 3         1004     Dwight     Schrute   123-543-23
# 4         1005        Jon        Snow   876-678-34
# 5         1006        Ron     Swanson   304-762-24
# 6         1007       Jeff      Winger           --
# 7         1008   Sherlock      Holmes   876-678-34
# 8         1009    Gandalf         NaN           --
# 9         1010      Peter      Parker   123-545-54
# 10        1011    Samwise      Gamgee           --
# 11        1012      Harry      Potter   706-695-03
# 12        1013        Don      Draper   123-543-23
# 13        1014     Leslie       Knope   876-678-34
# 14        1015       Toby  Flenderson   304-762-24
# 15        1016        Ron     Weasley   123-545-54
# 16        1017   Michael        Scott   123-643-97
# ...

# %%
df["Do_Not_Contact"]= df["Do_Not_Contact"].str.replace('Yes', 'Y')
df["Do_Not_Contact"]=df["Do_Not_Contact"].str.replace('No', 'N')

# %%
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   123-545-54
# 1         1002       Abed       Nadir   123-643-97
# 2         1003     Walter       White   706-695-03
# 3         1004     Dwight     Schrute   123-543-23
# 4         1005        Jon        Snow   876-678-34
# 5         1006        Ron     Swanson   304-762-24
# 6         1007       Jeff      Winger           --
# 7         1008   Sherlock      Holmes   876-678-34
# 8         1009    Gandalf         NaN           --
# 9         1010      Peter      Parker   123-545-54
# 10        1011    Samwise      Gamgee           --
# 11        1012      Harry      Potter   706-695-03
# 12        1013        Don      Draper   123-543-23
# 13        1014     Leslie       Knope   876-678-34
# 14        1015       Toby  Flenderson   304-762-24
# 15        1016        Ron     Weasley   123-545-54
# 16        1017   Michael        Scott   123-643-97
# ...

# %%
df = df.replace('N/a','')

# %%
df.replace('NaN','')
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   123-545-54
# 1         1002       Abed       Nadir   123-643-97
# 2         1003     Walter       White   706-695-03
# 3         1004     Dwight     Schrute   123-543-23
# 4         1005        Jon        Snow   876-678-34
# 5         1006        Ron     Swanson   304-762-24
# 6         1007       Jeff      Winger           --
# 7         1008   Sherlock      Holmes   876-678-34
# 8         1009    Gandalf                       --
# 9         1010      Peter      Parker   123-545-54
# 10        1011    Samwise      Gamgee           --
# 11        1012      Harry      Potter   706-695-03
# 12        1013        Don      Draper   123-543-23
# 13        1014     Leslie       Knope   876-678-34
# 14        1015       Toby  Flenderson   304-762-24
# 15        1016        Ron     Weasley   123-545-54
# 16        1017   Michael        Scott   123-643-97
# ...

# %%
df = df.fillna('')

# %%
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   123-545-54
# 1         1002       Abed       Nadir   123-643-97
# 2         1003     Walter       White   706-695-03
# 3         1004     Dwight     Schrute   123-543-23
# 4         1005        Jon        Snow   876-678-34
# 5         1006        Ron     Swanson   304-762-24
# 6         1007       Jeff      Winger           --
# 7         1008   Sherlock      Holmes   876-678-34
# 8         1009    Gandalf                       --
# 9         1010      Peter      Parker   123-545-54
# 10        1011    Samwise      Gamgee           --
# 11        1012      Harry      Potter   706-695-03
# 12        1013        Don      Draper   123-543-23
# 13        1014     Leslie       Knope   876-678-34
# 14        1015       Toby  Flenderson   304-762-24
# 15        1016        Ron     Weasley   123-545-54
# 16        1017   Michael        Scott   123-643-97
# ...

# %%
for x in df.index: 
    if df.loc[x, "Do_Not_Contact"] == 'Y':
         df.drop (x, inplace = True)

# %%
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   123-545-54
# 2         1003     Walter       White   706-695-03
# 4         1005        Jon        Snow   876-678-34
# 6         1007       Jeff      Winger           --
# 7         1008   Sherlock      Holmes   876-678-34
# 8         1009    Gandalf                       --
# 9         1010      Peter      Parker   123-545-54
# 10        1011    Samwise      Gamgee           --
# 11        1012      Harry      Potter   706-695-03
# 12        1013        Don      Draper   123-543-23
# 13        1014     Leslie       Knope   876-678-34
# 14        1015       Toby  Flenderson   304-762-24
# 15        1016        Ron     Weasley   123-545-54
# 16        1017   Michael        Scott   123-643-97
# 17        1018      Clark        Kent   706-695-03
# 19        1020     Anakin   Skywalker   876-678-34
#
#                            Address Paying Customer Do_Not_Contact  \
# ...

# %%
for x in df.index: 
    if df.loc[x, "Phone_Number"] == '':
         df.drop (x, inplace = True)

# %%
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   123-545-54
# 2         1003     Walter       White   706-695-03
# 4         1005        Jon        Snow   876-678-34
# 6         1007       Jeff      Winger           --
# 7         1008   Sherlock      Holmes   876-678-34
# 8         1009    Gandalf                       --
# 9         1010      Peter      Parker   123-545-54
# 10        1011    Samwise      Gamgee           --
# 11        1012      Harry      Potter   706-695-03
# 12        1013        Don      Draper   123-543-23
# 13        1014     Leslie       Knope   876-678-34
# 14        1015       Toby  Flenderson   304-762-24
# 15        1016        Ron     Weasley   123-545-54
# 16        1017   Michael        Scott   123-643-97
# 17        1018      Clark        Kent   706-695-03
# 19        1020     Anakin   Skywalker   876-678-34
#
#                            Address Paying Customer Do_Not_Contact  \
# ...

# %%
for x in df.index: 
    if df.loc[x, "Phone_Number"] == '--':
         df.drop (x, inplace = True)

# %%
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   123-545-54
# 2         1003     Walter       White   706-695-03
# 4         1005        Jon        Snow   876-678-34
# 7         1008   Sherlock      Holmes   876-678-34
# 9         1010      Peter      Parker   123-545-54
# 11        1012      Harry      Potter   706-695-03
# 12        1013        Don      Draper   123-543-23
# 13        1014     Leslie       Knope   876-678-34
# 14        1015       Toby  Flenderson   304-762-24
# 15        1016        Ron     Weasley   123-545-54
# 16        1017   Michael        Scott   123-643-97
# 17        1018      Clark        Kent   706-695-03
# 19        1020     Anakin   Skywalker   876-678-34
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire               Y              N
# 2               298 Drugs Driveway               N
# ...

# %%
for x in df.index: 
    if df.loc[x, "Do_Not_Contact"] == '':
         df.drop (x, inplace = True)

# %%
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   123-545-54
# 4         1005        Jon        Snow   876-678-34
# 7         1008   Sherlock      Holmes   876-678-34
# 9         1010      Peter      Parker   123-545-54
# 12        1013        Don      Draper   123-543-23
# 13        1014     Leslie       Knope   876-678-34
# 14        1015       Toby  Flenderson   304-762-24
# 15        1016        Ron     Weasley   123-545-54
# 16        1017   Michael        Scott   123-643-97
# 19        1020     Anakin   Skywalker   876-678-34
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire               Y              N
# 4                 123 Dragons Road               Y              N
# 7                    98 Clue Drive               N              N
# 9       25th Main Street, New York               Y              N
# 12                2039 Main Street               Y              N
# ...

# %%
df.reset_index()
# Out:
#    index  CustomerID First_Name   Last_Name Phone_Number  \
# 0      0        1001      Frodo     Baggins   123-545-54
# 1      4        1005        Jon        Snow   876-678-34
# 2      7        1008   Sherlock      Holmes   876-678-34
# 3      9        1010      Peter      Parker   123-545-54
# 4     12        1013        Don      Draper   123-543-23
# 5     13        1014     Leslie       Knope   876-678-34
# 6     14        1015       Toby  Flenderson   304-762-24
# 7     15        1016        Ron     Weasley   123-545-54
# 8     16        1017   Michael        Scott   123-643-97
# 9     19        1020     Anakin   Skywalker   876-678-34
#
#                           Address Paying Customer Do_Not_Contact  \
# 0           123 Shire Lane, Shire               Y              N
# 1                123 Dragons Road               Y              N
# 2                   98 Clue Drive               N              N
# 3      25th Main Street, New York               Y              N
# ...

# %%
df = df.reset_index(drop = True)

# %%
df
# Out:
#    CustomerID First_Name   Last_Name Phone_Number  \
# 0        1001      Frodo     Baggins   123-545-54
# 1        1005        Jon        Snow   876-678-34
# 2        1008   Sherlock      Holmes   876-678-34
# 3        1010      Peter      Parker   123-545-54
# 4        1013        Don      Draper   123-543-23
# 5        1014     Leslie       Knope   876-678-34
# 6        1015       Toby  Flenderson   304-762-24
# 7        1016        Ron     Weasley   123-545-54
# 8        1017   Michael        Scott   123-643-97
# 9        1020     Anakin   Skywalker   876-678-34
#
#                           Address Paying Customer Do_Not_Contact  \
# 0           123 Shire Lane, Shire               Y              N
# 1                123 Dragons Road               Y              N
# 2                   98 Clue Drive               N              N
# 3      25th Main Street, New York               Y              N
# 4                2039 Main Street               Y              N
# ...

# %%
df.dropna(subset="Phone_Number"), implace =True)
